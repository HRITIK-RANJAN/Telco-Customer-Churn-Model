# %%
import pandas as pd

# %%
df=pd.read_csv("prepared.csv")
df.head()
# Out:
#    Unnamed: 0  SeniorCitizen  MonthlyCharges  TotalCharges  Churn  \
# 0           0              0           29.85         29.85      0
# 1           1              0           56.95       1889.50      0
# 2           2              0           53.85        108.15      1
# 3           3              0           42.30       1840.75      0
# 4           4              0           70.70        151.65      1
#
#    gender_Female  gender_Male  Partner_No  Partner_Yes  Dependents_No  ...  \
# 0           True        False       False         True           True  ...
# 1          False         True        True        False           True  ...
# 2          False         True        True        False           True  ...
# 3          False         True        True        False           True  ...
# 4           True        False        True        False           True  ...
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                    False
# ...

# %%
df=df.drop('Unnamed: 0',axis=1)
x=df.drop('Churn',axis=1)
x
# Out:
#       SeniorCitizen  MonthlyCharges  TotalCharges  gender_Female  gender_Male  \
# 0                 0           29.85         29.85           True        False
# 1                 0           56.95       1889.50          False         True
# 2                 0           53.85        108.15          False         True
# 3                 0           42.30       1840.75          False         True
# 4                 0           70.70        151.65           True        False
# ...             ...             ...           ...            ...          ...
# 7027              0           84.80       1990.50          False         True
# 7028              0          103.20       7362.90           True        False
# 7029              0           29.60        346.45           True        False
# 7030              1           74.40        306.60          False         True
# 7031              0          105.65       6844.50          False         True
#
# ...

# %%
y=df['Churn']
y.head(5)
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Churn, dtype: int64

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.metrics import classification_report

# Assuming 'X' is your feature matrix and 'y' is the target variable (churn or no churn)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Standardize the features (if needed)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

models = {
    'Logistic Regression': LogisticRegression(max_iter=1000, C=1.0),  # Add your best hyperparameters
    'Decision Tree': DecisionTreeClassifier(criterion='gini', max_depth=8, min_samples_leaf=4),
    'Random Forest': RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=10, min_samples_leaf=2),
    'Gradient Boosting': GradientBoostingClassifier(learning_rate=0.1, n_estimators=100, max_depth=3),
    'Support Vector Machine': SVC(kernel='rbf', C=1.0, decision_function_shape='ovo'),
    'K-Nearest Neighbors': KNeighborsClassifier(n_neighbors=5),
    'Naive Bayes': GaussianNB(),
    'Neural Network': MLPClassifier(hidden_layer_sizes=(100,), max_iter=500)
}

# Initialize an empty DataFrame to store results
results_df = pd.DataFrame(columns=['Model', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'ROC AUC'])


# Train and evaluate each model
for model_name, model in models.items():
    # Train the model
    model.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Evaluate the model
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_pred)
    print(model_name," -->\n ",classification_report(y_test, y_pred, labels=[0,1]))
    # Append results to the DataFrame
    results_df = results_df._append({
        'Model': model_name,
        'Accuracy': accuracy,
        'Precision': precision,
        'Recall': recall,
        'F1 Score': f1,
        'ROC AUC': roc_auc
    }, ignore_index=True)

# Display the results table
results_df
# Out:
# Logistic Regression  -->
#                 precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86      1033
#            1       0.62      0.46      0.53       374
#
#     accuracy                           0.78      1407
#    macro avg       0.72      0.68      0.69      1407
# weighted avg       0.77      0.78      0.77      1407
#
# Decision Tree  -->
#                 precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84      1033
#            1       0.56      0.52      0.54       374
#
#     accuracy                           0.76      1407
#    macro avg       0.69      0.68      0.69      1407
# weighted avg       0.76      0.76      0.76      1407
#
# Random Forest  -->
#                 precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86      1033
#            1       0.63      0.47      0.54       374
#
#     accuracy                           0.79      1407
# ...

# %%
from imblearn.combine import SMOTEENN

# %%
# Assuming 'X' is your feature matrix and 'y' is the target variable (churn or no churn)
sm = SMOTEENN()
X_resampled, y_resampled = sm.fit_resample(x,y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled , test_size=0.2, random_state=42)

# Standardize the features (if needed)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Define models
models = {
    'Logistic Regression': LogisticRegression(max_iter=1000, C=1.0),  # Add your best hyperparameters
    'Decision Tree': DecisionTreeClassifier(criterion='gini', max_depth=8, min_samples_leaf=4),
    'Random Forest': RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=10, min_samples_leaf=2),
    'Gradient Boosting': GradientBoostingClassifier(learning_rate=0.1, n_estimators=100, max_depth=3),
    'Support Vector Machine': SVC(kernel='rbf', C=1.0, decision_function_shape='ovo'),
    'K-Nearest Neighbors': KNeighborsClassifier(n_neighbors=5),
    'Naive Bayes': GaussianNB(),
    'Neural Network': MLPClassifier(hidden_layer_sizes=(100,), max_iter=500)
}

# Initialize an empty DataFrame to store results
results_df = pd.DataFrame(columns=['Model', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'ROC AUC'])


# Train and evaluate each model
for model_name, model in models.items():
    # Train the model
    model.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Evaluate the model
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_pred)
    print(model_name," -->\n ",classification_report(y_test, y_pred, labels=[0,1]))
    # Append results to the DataFrame
    results_df = results_df._append({
        'Model': model_name,
        'Accuracy': accuracy*100,
        'Precision': precision*100,
        'Recall': recall*100,
        'F1 Score': f1*100,
        'ROC AUC': roc_auc*100
    }, ignore_index=True)

# Display the results table
results_df
# Out:
# Logistic Regression  -->
#                 precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94       559
#            1       0.95      0.94      0.95       624
#
#     accuracy                           0.94      1183
#    macro avg       0.94      0.94      0.94      1183
# weighted avg       0.94      0.94      0.94      1183
#
# Decision Tree  -->
#                 precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93       559
#            1       0.94      0.94      0.94       624
#
#     accuracy                           0.94      1183
#    macro avg       0.94      0.94      0.94      1183
# weighted avg       0.94      0.94      0.94      1183
#
# Random Forest  -->
#                 precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95       559
#            1       0.95      0.95      0.95       624
#
#     accuracy                           0.95      1183
# ...

# %%
from sklearn.decomposition import PCA
pca = PCA(0.9)
xr_train_pca = pca.fit_transform(X_train)
xr_test_pca = pca.transform(X_test)
explained_variance = pca.explained_variance_ratio_

# %%
model=GradientBoostingClassifier(learning_rate=0.1, n_estimators=100, max_depth=3)

# %%
model.fit(xr_train_pca,y_train)
# Out:
# GradientBoostingClassifier()

# %%
yr_predict_pca = model.predict(xr_test_pca)

# %%
model_score_r_pca = model.score(xr_test_pca, y_test)

# %%
print(model_score_r_pca)
print(classification_report(y_test, yr_predict_pca))
# Out:
# 0.9315300084530854
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.93       559
#            1       0.93      0.94      0.94       624
#
#     accuracy                           0.93      1183
#    macro avg       0.93      0.93      0.93      1183
# weighted avg       0.93      0.93      0.93      1183

# %%
lr = LogisticRegression(max_iter=1000, C=1.0)
gb =GradientBoostingClassifier(learning_rate=0.1, n_estimators=100, max_depth=3) 
rf = RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=10, min_samples_leaf=2)
svm=SVC(kernel='rbf', C=1.0, decision_function_shape='ovo')

from sklearn.ensemble import VotingClassifier
voting = VotingClassifier(estimators=[('lr', lr), ('gb', gb), ('rf', rf)],voting='soft')
voting.fit(X_train,y_train)
# Out:
# VotingClassifier(estimators=[('lr', LogisticRegression(max_iter=1000)),
#                              ('gb', GradientBoostingClassifier()),
#                              ('rf',
#                               RandomForestClassifier(max_depth=10,
#                                                      min_samples_leaf=2,
#                                                      n_estimators=150))],
#                  voting='soft')

# %%
y_pred = voting.predict(X_test)
print("Accuracy",accuracy_score(y_test,y_pred))
print("Precision",precision_score(y_test,y_pred))
# Out:
# Accuracy 0.9509721048182587
# Precision 0.9477848101265823

# %%
from sklearn.ensemble import StackingClassifier
estimators=[('lr', lr), ('gb', gb), ('rf', rf)]
final_estimator= SVC(kernel='rbf', C=1.0, decision_function_shape='ovo')
clf = StackingClassifier(estimators=estimators, final_estimator=final_estimator)
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
print("Accuracy",accuracy_score(y_test,y_pred))
print("Precision",precision_score(y_test,y_pred))
# Out:
# Accuracy 0.9518174133558749
# Precision 0.9536

# %%
print(classification_report(y_test, y_pred, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       559
#            1       0.95      0.96      0.95       624
#
#     accuracy                           0.95      1183
#    macro avg       0.95      0.95      0.95      1183
# weighted avg       0.95      0.95      0.95      1183

# %%
import pickle
pickle.dump(clf,open('model.pkl','wb'))

# %%
svm=SVC(kernel='rbf', C=1.0, decision_function_shape='ovo')
from sklearn.ensemble import StackingClassifier
estimators=[ ('gb', gb), ('rf', rf),('svm',svm)]
final_estimator=  LogisticRegression(max_iter=1000, C=1.0)
clf = StackingClassifier(estimators=estimators, final_estimator=final_estimator)
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
print("Accuracy",accuracy_score(y_test,y_pred))
print("Precision",precision_score(y_test,y_pred))
# Out:
# Accuracy 0.9535080304311073
# Precision 0.9552
